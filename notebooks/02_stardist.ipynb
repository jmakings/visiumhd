# %% [markdown]
# # Nuclei segmentation using StarDist
# https://squidpy.readthedocs.io/en/stable/notebooks/tutorials/tutorial_stardist.html

# %%
# Out:
# __init__.py (31): The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import squidpy
#
# File ~/miniforge3/envs/visiumhd/lib/python3.10/site-packages/squidpy/__init__.py:6
#       3 from importlib import metadata
#       4 from importlib.metadata import PackageMetadata
# ----> 6 from squidpy import datasets, gr, im, pl, read, tl
#       8 try:
#       9     md: PackageMetadata = metadata.metadata(__name__)
#
# File ~/miniforge3/envs/visiumhd/lib/python3.10/site-packages/squidpy/datasets/__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from squidpy.datasets._10x_datasets import visium, visium_hne_sdata
#       4 from squidpy.datasets._dataset import *  # noqa: F403
#       5 from squidpy.datasets._image import *  # noqa: F403
#
# File ~/miniforge3/envs/visiumhd/lib/python3.10/site-packages/squidpy/datasets/_10x_datasets.py:13
#       6 from pathlib import Path
#       7 from typing import (
#       8     Literal,
#       9     NamedTuple,
#      10     Union,  # noqa: F401
#      11 )
# ---> 13 import spatialdata as sd
#      14 from anndata import AnnData
#      15 from scanpy import _utils
#
# File ~/miniforge3/envs/visiumhd/lib/python3.10/site-packages/spatialdata/__init__.py:60
#      20 __version__ = version("spatialdata")
#      22 __all__ = [
#      23     "models",
#      24     "transformations",
#    (...)
#      57     "sanitize_name",
#      58 ]
# ---> 60 from spatialdata import dataloader, datasets, models, transformations
#      61 from spatialdata._core._deepcopy import deepcopy
#      62 from spatialdata._core._utils import sanitize_name, sanitize_table
#
# File ~/miniforge3/envs/visiumhd/lib/python3.10/site-packages/spatialdata/datasets.py:11
#       9 import pandas as pd
#      10 import scipy
# ---> 11 from anndata import AnnData
#      12 from dask.dataframe import DataFrame as DaskDataFrame
#      13 from geopandas import GeoDataFrame
#
# File ~/miniforge3/envs/visiumhd/lib/python3.10/site-packages/anndata/__init__.py:19
#      15 if sys.version_info < (3, 11):
#      16     # Backport package for exception groups
#      17     import exceptiongroup  # noqa: F401
# ---> 19 from ._core.anndata import AnnData
#      20 from ._core.merge import concat
#      21 from ._core.raw import Raw
#
# File ~/miniforge3/envs/visiumhd/lib/python3.10/site-packages/anndata/_core/anndata.py:16
#      13 from textwrap import dedent
#      14 from typing import TYPE_CHECKING, cast
# ---> 16 import h5py
#      17 import numpy as np
#      18 import pandas as pd
#
# ModuleNotFoundError: No module named 'h5py'

# %%
from stardist.models import StarDist2D
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/miniforge3/envs/visiumhd/lib/python3.10/site-packages/csbdeep/models/__init__.py:5
#       4 try:
# ----> 5     import tensorflow
#       6     del tensorflow
#
# ModuleNotFoundError: No module named 'tensorflow'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from stardist.models import StarDist2D
#
# File ~/miniforge3/envs/visiumhd/lib/python3.10/site-packages/stardist/models/__init__.py:3
#       1 from __future__ import absolute_import, print_function
# ----> 3 from .model2d import Config2D, StarDist2D, StarDistData2D
#       4 from .model3d import Config3D, StarDist3D, StarDistData3D
#       6 from csbdeep.utils import backend_channels_last
#
# File ~/miniforge3/envs/visiumhd/lib/python3.10/site-packages/stardist/models/model2d.py:8
#       5 import math
#       6 from tqdm import tqdm
# ----> 8 from csbdeep.models import BaseConfig
#       9 from csbdeep.internals.blocks import unet_block
#      10 from csbdeep.utils import _raise, backend_channels_last, axes_check_and_normalize, axes_dict
#
# File ~/miniforge3/envs/visiumhd/lib/python3.10/site-packages/csbdeep/models/__init__.py:9
#       7 except ModuleNotFoundError as e:
#       8     from six import raise_from
# ----> 9     raise_from(RuntimeError('Please install TensorFlow: https://www.tensorflow.org/install/'), e)
#      12 import tensorflow, sys
#      13 from ..utils.tf import keras_import, IS_TF_1, BACKEND as K
#
# File <string>:3, in raise_from(value, from_value)
#
# RuntimeError: Please install TensorFlow: https://www.tensorflow.org/install/

# %%
# Import the recommended normalization technique for stardist.
from csbdeep.utils import normalize

# %%
import numpy as np

import matplotlib.pyplot as plt

# Import squidpy and additional packages needed for this tutorial.
import squidpy as sq
